# %% [markdown]
# # Overview
# This notebook shows how to quicky start using the Hadamard parametrization for optimization over the probability simplex. It accompanies the paper "From the simplex to the sphere: Faster constrained optimization using the Hadamard parametrization"
#
# ## Terminology
#  - **Hadamard parametrization:** $x = z\cdot z$ where $\cdot$ is the component-wise (or Hadamard) product.
#  - **Probability simplex:** $\Delta_{n} \triangleq \{x \in \mathbb{R}^{n}: \ x \geq 0 \text{ and } \sum_{k}x_k = 1 \}$
#
# Thoroughout, we use the notational convention that $x \in \Delta^{n}$ while $z \in \mathbb{S}^n$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import time as time
from Riemannian_utils import *
from SimplexProjections import *
from ExpDescentAlg_utils import ExpDescentAlg
from PGD_Linesearch import *
from Riemannian_algs import HadRGD_BB, HadRGD_AW
from PGD_Variants import PGD
from utils import *

# %% [markdown]
# ## Setting up the cost function
# The next block of code defines the cost function: $f(x) = \left\|Ax - b\right\|_{2}^{2}$. Although it is underdetermined, we choose $b = Ax_{\text{true}}$ so $\min f(x) = 0$.
#
# For simplicity, we define it twice: once in terms of the original variable x and once in terms of the reparametrized variable z.

# %%
n=5000
m=500
A = np.random.rand(m,n)
x_true = SampleSimplex(n)
b = np.dot(A,x_true)
s = np.linalg.svd(A, full_matrices=False, compute_uv=False)
Lipschitz_constant = s[0]

def cost(x):
    '''
    Least squares loss function.
    '''
    temp = np.dot(A,x) - b
    return np.dot(temp,temp)/2

def cost_grad(x):
    '''
    Gradient of least squares loss function.
    '''
    temp = np.dot(A,x) - b
    return np.dot(A.T,temp)

def cost_H(z):
    '''
    Hadamard parametrized least squares cost. Mainly for use with autodiff.
    '''
    return np.sum((np.dot(A,z*z) - b)**2)/2

def cost_H_grad(z):
    '''
    Gradient of Hadamard parametrized least squares cost. For use in line search.
    '''
    return np.dot(A.T,np.dot(A,z*z) - b)*z

# %% [markdown]
# ## Parameters
# The next block of code sets parameters.

# %%
x0 = SampleSimplex(n)
z0 = np.sqrt(x0)

# %% [markdown]
# ## Armijo-Wolfe
# The next cell implements HadRGD-AW

# %%
z = copy.copy(z0)
default_step_size = 10.0
AWOpt = HadRGD_AW(cost_H, cost_H_grad, z, default_step_size)
AWOpt_time = [0]
AWOpt_Error = [cost_H(z)]

# %%
start_time = time.time()
for k in range(100):
    err = AWOpt.step()
    AWOpt_time.append(time.time() - start_time)
    AWOpt_Error.append(err)
    print(err)
# Out:
# number of AW iterations= 0
# 0.008508100553833931
# number of AW iterations= 1
# 0.005311113146988976
# number of AW iterations= 1
# 0.0034046977421241923
# number of AW iterations= 2
# 0.0011243242436795875
# number of AW iterations= 2
# 0.0005370860624428224
# number of AW iterations= 2
# 0.00033271622129232197
# number of AW iterations= 2
# 0.0002174778395720899
# number of AW iterations= 2
# 0.00015712665473258905
# number of AW iterations= 2
# 0.00011617010019839889
# number of AW iterations= 2
# 9.050131882835073e-05
# number of AW iterations= 2
# 7.195385490420803e-05
# number of AW iterations= 2
# 5.91170644176899e-05
# number of AW iterations= 2
# 4.959326547667558e-05
# number of AW iterations= 2
# 4.266760976676687e-05
# number of AW iterations= 2
# 3.7470202185397526e-05
# number of AW iterations= 2
# 3.3677828569312204e-05
# number of AW iterations= 2
# 3.0880500422422416e-05
# number of AW iterations= 2
# 2.8971102221300415e-05
# number of AW iterations= 2
# 2.7726118782205248e-05
# number of AW iterations= 2
# 2.711716238635468e-05
# number of AW iterations= 2
# 2.705812155985691e-05
# number of AW iterations= 3
# 6.960846749353542e-06
# number of AW iterations= 3
# 1.8724172584041001e-06
# number of AW iterations= 3
# 5.223438875387941e-07
# number of AW iterations= 3
# 1.5075489176431913e-07
# number of AW iterations= 3
# 4.4551705596555845e-08
# number of AW iterations= 3
# 1.3443516434004822e-08
# number of AW iterations= 3
# 4.1173620004627755e-09
# number of AW iterations= 3
# 1.2775011097602433e-09
# number of AW iterations= 3
# 4.006154516820478e-10
# number of AW iterations= 3
# 1.269827637258189e-10
# number of AW iterations= 3
# 4.0724078442529787e-11
# number of AW iterations= 3
# 1.3258007017992267e-11
# number of AW iterations= 3
# 4.405826572695018e-12
# number of AW iterations= 3
# 1.5072789396736802e-12
# number of AW iterations= 3
# 5.367991873146747e-13
# number of AW iterations= 2
# 5.204379687472086e-13
# number of AW iterations= 3
# 1.784422042224882e-13
# number of AW iterations= 3
# 6.366294204077986e-14
# number of AW iterations= 2
# 6.238467275868092e-14
# number of AW iterations= 3
# 2.14463244542328e-14
# number of AW iterations= 3
# 7.67417164497323e-15
# number of AW iterations= 2
# 7.55242889895593e-15
# number of AW iterations= 3
# 2.6049207923323008e-15
# number of AW iterations= 3
# 9.360246329449609e-16
# number of AW iterations= 2
# 9.211504505603598e-16
# number of AW iterations= 3
# 3.1899103792286163e-16
# number of AW iterations= 3
# 1.1523194959273384e-16
# number of AW iterations= 2
# 1.1302919851893752e-16
# number of AW iterations= 3
# 3.932627399358581e-17
# number of AW iterations= 3
# 1.4296600443728033e-17
# number of AW iterations= 2
# 1.3940174302312567e-17
# number of AW iterations= 3
# 4.87649614592579e-18
# number of AW iterations= 3
# 1.7858493884295393e-18
# number of AW iterations= 2
# 1.726994576209372e-18
# number of AW iterations= 3
# 6.078351557076479e-19
# number of AW iterations= 3
# 2.244550319489293e-19
# number of AW iterations= 2
# 2.1481838130716316e-19
# number of AW iterations= 3
# 7.612691235017773e-20
# number of AW iterations= 3
# 2.837230945290334e-20
# number of AW iterations= 2
# 2.682050331192825e-20
# number of AW iterations= 3
# 9.577187567641545e-21
# number of AW iterations= 3
# 3.605934453993317e-21
# number of AW iterations= 2
# 3.360388474961647e-21
# number of AW iterations= 3
# 1.2101325926093241e-21
# number of AW iterations= 3
# 4.607451137720718e-22
# number of AW iterations= 2
# 4.225220157067575e-22
# number of AW iterations= 3
# 1.5357642452997495e-22
# number of AW iterations= 2
# 1.5205674759181418e-22
# number of AW iterations= 3
# 5.331668211861795e-23
# number of AW iterations= 3
# 1.9581307445639768e-23
# number of AW iterations= 2
# 1.9105348076726227e-23
# number of AW iterations= 3
# 6.752968407490912e-24
# number of AW iterations= 3
# 2.507303830019001e-24
# number of AW iterations= 2
# 2.4085723780302064e-24
# number of AW iterations= 3
# 8.579904950305757e-25
# number of AW iterations= 3
# 3.218658820042098e-25
# number of AW iterations= 2
# 3.0356083462546264e-25
# number of AW iterations= 3
# 1.0936071635939404e-25
# number of AW iterations= 3
# 4.193093382981882e-26
# number of AW iterations= 2
# 3.911709933651854e-26
# number of AW iterations= 3
# 1.4280223573527148e-26
# number of AW iterations= 2
# 1.4098594513075832e-26
# number of AW iterations= 3
# 4.91394246036999e-27
# number of AW iterations= 3
# 1.860164829390256e-27
# number of AW iterations= 3
# 7.543898407043913e-28
# number of AW iterations= 2
# 7.085588710037971e-28
# number of AW iterations= 3
# 2.921219724767449e-28
# number of AW iterations= 3
# 1.3131606658414378e-28
# number of AW iterations= 3
# 7.531926826509602e-29
# number of AW iterations= 3
# 5.563626423345847e-29
# number of AW iterations= 3
# 4.229650306665472e-29
# number of AW iterations= 3
# 3.4236871435383014e-29
# number of AW iterations= 3
# 2.763016135415704e-29
# number of AW iterations= 3
# 2.0833939766403363e-29
# number of AW iterations= 3
# 2.078309521587154e-29
# number of AW iterations= 4
# 1.618859674054135e-29
# number of AW iterations= 4
# 1.2919138066949578e-29
# number of AW iterations= 5
# 1.1629535376187885e-29
# number of AW iterations= 5
# 1.0706629746837522e-29

# %% [markdown]
# ## Barzilei-Borwein
#
# The next cell implements a Barzilei-Borwein scheme, as described [here](https://scholarship.rice.edu/bitstream/handle/1911/102167/TR10-26.PDF?sequence=1)

# %%
alpha_def = 3.0
rho1 = 0.1
beta = 0.5
eta = 0.5
z = copy.copy(z0)
BBOpt_Error = [cost_H(z)]
BBOpt_time = [0]
BBOpt = HadRGD_BB(cost_H, cost_H_grad, alpha_def, rho1, beta, eta, z)

# %%
start_time = time.time()
for k in range(50):
    err = BBOpt.step()
    BBOpt_time.append(time.time() - start_time)
    BBOpt_Error.append(err)
    print(err)
# Out:
# 0.002076429712571644
# 0.00047805384850373866
# 8.307928830599866e-05
# 2.5290534899901712e-05
# 4.845739266512307e-05
# 1.7681138672967454e-06
# 6.99370852163043e-07
# 4.1476637347233323e-07
# 1.4315168383932265e-08
# 3.93089333385307e-08
# 2.187142623343122e-08
# 9.006169454145992e-11
# 3.440620683469875e-11
# 1.9226785316320684e-11
# 2.603483350511372e-12
# 6.685128224701837e-13
# 1.1838825735376251e-12
# 1.9447083542841e-13
# 2.1703387784474278e-14
# 2.2900344826956985e-15
# 1.3459856959124687e-15
# 3.3335275292515657e-16
# 5.132719430361557e-17
# 9.188414646997001e-17
# 4.9469909587324807e-17
# 1.7371402598585293e-18
# 3.352847177185e-19
# 2.18423832850108e-19
# 2.9645152268697375e-20
# 2.3125999470208176e-20
# 2.0316782257334876e-20
# 5.7950878853430585e-22
# 1.1410646387101712e-22
# 2.121787168522715e-23
# 1.3570643881074884e-23
# 3.1106336667656584e-24
# 4.532689066364586e-25
# 3.621101900808025e-24
# 2.1760865813031233e-25
# 1.798554484543704e-26
# 5.280946129828466e-27
# 4.487370548103594e-28
# 2.174944982476728e-28
# 1.4642460181187277e-28
# 6.984346424721423e-29
# 4.673692714643393e-29
# 3.7942360648384056e-29
# 2.9341927888728416e-29
# 2.550239395159802e-29
# 2.057047255001119e-29

# %% [markdown]
# ## PGD on simplex with line search
#
# The next two blocks of code implement both variant of projected gradient descent with line search.

# %%
x = copy.copy(x0)
opt = PGDL_Feasible(cost, cost_grad, CondatProject, x, 0.1, 0.75, 1e-4)
Error_PGDL = [cost(x0)]
Time_PGDL = [0]

# %%
start_time = time.time()
for _ in range(100):
    _, err = opt.step()
    Time_PGDL.append(time.time() - start_time)
    Error_PGDL.append(err)
    print(err)
# Out:
# Number of PGDL iterations is 5
# 0.0044131607159971515
# Number of PGDL iterations is 6
# 0.002020578928743592
# Number of PGDL iterations is 7
# 0.0008646316068106491
# Number of PGDL iterations is 8
# 0.0004206906207805978
# Number of PGDL iterations is 9
# 0.0001955238870027656
# Number of PGDL iterations is 10
# 8.906429401693114e-05
# Number of PGDL iterations is 11
# 3.3416187102340165e-05
# Number of PGDL iterations is 11
# 3.043509902335019e-05
# Number of PGDL iterations is 12
# 1.1166623240402974e-05
# Number of PGDL iterations is 12
# 6.708612943529713e-06
# Number of PGDL iterations is 12
# 5.413881730642242e-06
# Number of PGDL iterations is 12
# 4.743476006107705e-06
# Number of PGDL iterations is 12
# 4.4799489532172674e-06
# Number of PGDL iterations is 12
# 4.219250981788906e-06
# Number of PGDL iterations is 12
# 4.1776645321073245e-06
# Number of PGDL iterations is 12
# 4.032272517807808e-06
# Number of PGDL iterations is 13
# 1.0528760373151669e-06
# Number of PGDL iterations is 13
# 3.697328717745505e-07
# Number of PGDL iterations is 13
# 1.5413781188282713e-07
# Number of PGDL iterations is 13
# 6.917676826403546e-08
# Number of PGDL iterations is 13
# 3.2518658863894996e-08
# Number of PGDL iterations is 13
# 1.5743096273325424e-08
# Number of PGDL iterations is 13
# 7.763900083088619e-09
# Number of PGDL iterations is 13
# 3.878882266265196e-09
# Number of PGDL iterations is 13
# 1.9544000914774554e-09
# Number of PGDL iterations is 13
# 9.92091422433022e-10
# Number of PGDL iterations is 13
# 5.063904967231632e-10
# Number of PGDL iterations is 13
# 2.596075129355054e-10
# Number of PGDL iterations is 13
# 1.3354852264065488e-10
# Number of PGDL iterations is 13
# 6.889402723668844e-11
# Number of PGDL iterations is 13
# 3.562252645552607e-11
# Number of PGDL iterations is 13
# 1.8454896803382956e-11
# Number of PGDL iterations is 13
# 9.576515016848749e-12
# Number of PGDL iterations is 13
# 4.976312431270119e-12
# Number of PGDL iterations is 13
# 2.5889747792803834e-12
# Number of PGDL iterations is 13
# 1.3483408170810716e-12
# Number of PGDL iterations is 13
# 7.028575186605887e-13
# Number of PGDL iterations is 13
# 3.666777055544545e-13
# Number of PGDL iterations is 13
# 1.9143127605944174e-13
# Number of PGDL iterations is 13
# 1.0000465198801134e-13
# Number of PGDL iterations is 13
# 5.227320169942579e-14
# Number of PGDL iterations is 13
# 2.7337968016763307e-14
# Number of PGDL iterations is 13
# 1.430413028267443e-14
# Number of PGDL iterations is 13
# 7.487680066811043e-15
# Number of PGDL iterations is 13
# 3.92110404962944e-15
# Number of PGDL iterations is 13
# 2.0541454328198946e-15
# Number of PGDL iterations is 13
# 1.0764743802382704e-15
# Number of PGDL iterations is 13
# 5.643065818557923e-16
# Number of PGDL iterations is 13
# 2.959073515071957e-16
# Number of PGDL iterations is 13
# 1.5520895798607553e-16
# Number of PGDL iterations is 13
# 8.143108717384763e-17
# Number of PGDL iterations is 13
# 4.273354095611042e-17
# Number of PGDL iterations is 13
# 2.2430861528448598e-17
# Number of PGDL iterations is 13
# 1.1776469674727305e-17
# Number of PGDL iterations is 13
# 6.1840206091308624e-18
# Number of PGDL iterations is 13
# 3.2479409309623043e-18
# Number of PGDL iterations is 13
# 1.706165929322205e-18
# Number of PGDL iterations is 13
# 8.96408465098896e-19
# Number of PGDL iterations is 13
# 4.710408419585432e-19
# Number of PGDL iterations is 13
# 2.4755667964662737e-19
# Number of PGDL iterations is 13
# 1.3012152195109785e-19
# Number of PGDL iterations is 13
# 6.840389633250197e-20
# Number of PGDL iterations is 13
# 3.596401229214723e-20
# Number of PGDL iterations is 13
# 1.891062400420983e-20
# Number of PGDL iterations is 13
# 9.944791961688191e-21
# Number of PGDL iterations is 13
# 5.2303439057125396e-21
# Number of PGDL iterations is 13
# 2.751068830812341e-21
# Number of PGDL iterations is 13
# 1.44713497034534e-21
# Number of PGDL iterations is 13
# 7.612872102253832e-22
# Number of PGDL iterations is 13
# 4.0051257806142077e-22
# Number of PGDL iterations is 13
# 2.1072247767373315e-22
# Number of PGDL iterations is 13
# 1.1088217722483254e-22
# Number of PGDL iterations is 13
# 5.835094799211735e-23
# Number of PGDL iterations is 13
# 3.0712705856536756e-23
# Number of PGDL iterations is 13
# 1.6164655084779572e-23
# Number of PGDL iterations is 13
# 8.504485880350943e-24
# Number of PGDL iterations is 13
# 4.475687938720371e-24
# Number of PGDL iterations is 13
# 2.3559823433230896e-24
# Number of PGDL iterations is 13
# 1.2387389363972086e-24
# Number of PGDL iterations is 13
# 6.509422639124186e-25
# Number of PGDL iterations is 13
# 3.4326779545939646e-25
# Number of PGDL iterations is 13
# 1.8130037970626285e-25
# Number of PGDL iterations is 13
# 9.523164593087822e-26
# Number of PGDL iterations is 13
# 5.019642426098619e-26
# Number of PGDL iterations is 13
# 2.662371504679498e-26
# Number of PGDL iterations is 13
# 1.416348910773795e-26
# Number of PGDL iterations is 13
# 7.548853439604833e-27
# Number of PGDL iterations is 13
# 4.0141726422555614e-27
# Number of PGDL iterations is 13
# 2.1469049832304053e-27
# Number of PGDL iterations is 13
# 1.145165648652428e-27
# Number of PGDL iterations is 13
# 6.364351057024284e-28
# Number of PGDL iterations is 13
# 3.7591225100923375e-28
# Number of PGDL iterations is 13
# 2.434529524101017e-28
# Number of PGDL iterations is 13
# 1.6905196754248952e-28
# Number of PGDL iterations is 13
# 1.2893253568497014e-28
# Number of PGDL iterations is 13
# 1.1356669621667101e-28
# Number of PGDL iterations is 13
# 1.077889063835093e-28
# Number of PGDL iterations is 13
# 8.450980595971191e-29
# Number of PGDL iterations is 13
# 7.88260015078363e-29
# Number of PGDL iterations is 14
# 4.409763275064566e-29

# %%
## Now plot the results
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.semilogy(Error_PGDL, label="PGD w. line search", color = 'blue')
plt.semilogy(AWOpt_Error, label="HadRGD-AW", color = 'red')#, marker = 'o')
plt.semilogy(BBOpt_Error, label="HadRGD-BB", color = 'orange')#, marker = 'o')
plt.legend()
plt.xlabel('Num. Iterations')
plt.ylabel('Value of objective function')
#plt.savefig('HadRGD_Lin_Convergence.pdf')
plt.show()
